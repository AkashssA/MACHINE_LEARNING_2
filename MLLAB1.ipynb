# %% [markdown]
# <a href="https://colab.research.google.com/github/AkashssA/MACHINE_LEARNING_2/blob/main/MLLAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##implement data loading cleaning and exploratary data analysis eda on a given dataset using numpy panadas and matplotlib handling missing values summary ststatstics distrubution and correlation plots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("student.csv")

# %%
print(df.head())
# Out:
#    student_id  age  gender  studyhours  attendance marks result
# 0           1   18    Male           4        92.0    85   Pass
# 1           2   19  Female           6        95.0    91   Pass
# 2           3   18    Male          78        62.0  Pass    NaN
# 3           4   20  Female           7        98.0   NaN   Pass
# 4           5   19    Male           3        85.0   NaN   Pass

# %%
df.tail()
# Out:
#     student_id  age  gender  studyhours  attendance marks result
# 6            7   21    Male           5        90.0    88   Pass
# 7            8   20     NaN           2         NaN    55   Pass
# 8            9   19    Male           1        60.0    38   Fail
# 9           10   18  Female           6        96.0    89   Pass
# 10          10   18  Female           6        96.0    89   Pass

# %%
df.shape
# Out:
# (11, 7)

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'studyhours', 'attendance', 'marks',
#        'result'],
#       dtype='object')

# %%
df.dtypes
# Out:
# student_id      int64
# age             int64
# gender         object
# studyhours      int64
# attendance    float64
# marks          object
# result         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# student_id    0
# age           0
# gender        1
# studyhours    0
# attendance    1
# marks         3
# result        1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     student_id  age  gender  studyhours  attendance marks result
# 0            1   18    Male           4        92.0    85   Pass
# 1            2   19  Female           6        95.0    91   Pass
# 6            7   21    Male           5        90.0    88   Pass
# 8            9   19    Male           1        60.0    38   Fail
# 9           10   18  Female           6        96.0    89   Pass
# 10          10   18  Female           6        96.0    89   Pass

# %%
# Convert columns to numeric
df["age"] = pd.to_numeric(df["age"], errors="coerce")
df["studyhours"] = pd.to_numeric(df["studyhours"], errors="coerce")
df["attendance"] = pd.to_numeric(df["attendance"], errors="coerce")
df["marks"] = pd.to_numeric(df["marks"], errors="coerce")

# Replace missing values with mean
df["age"] = df["age"].fillna(df["age"].mean())
df["studyhours"] = df["studyhours"].fillna(df["studyhours"].mean())
df["attendance"] = df["attendance"].fillna(df["attendance"].mean())
df["marks"] = df["marks"].fillna(df["marks"].mean())

print(df)
# Out:
#     student_id  age  gender  studyhours  attendance  marks result
# 0            1   18    Male           4        92.0     85   Pass
# 1            2   19  Female           6        95.0     91   Pass
# 6            7   21    Male           5        90.0     88   Pass
# 8            9   19    Male           1        60.0     38   Fail
# 9           10   18  Female           6        96.0     89   Pass
# 10          10   18  Female           6        96.0     89   Pass

# %%
df["marks"] = pd.to_numeric(df["marks"], errors="coerce")

df["marks"] = df["marks"].fillna(df["marks"].median())

# %%
df
# Out:
#     student_id  age  gender  studyhours  attendance  marks result
# 0            1   18    Male           4        92.0     85   Pass
# 1            2   19  Female           6        95.0     91   Pass
# 6            7   21    Male           5        90.0     88   Pass
# 8            9   19    Male           1        60.0     38   Fail
# 9           10   18  Female           6        96.0     89   Pass
# 10          10   18  Female           6        96.0     89   Pass

# %%
df["gender"] = df["gender"].fillna(df["gender"].mode()[0])

print(df)
# Out:
#     student_id  age  gender  studyhours  attendance  marks result
# 0            1   18    Male           4        92.0     85   Pass
# 1            2   19  Female           6        95.0     91   Pass
# 6            7   21    Male           5        90.0     88   Pass
# 8            9   19    Male           1        60.0     38   Fail
# 9           10   18  Female           6        96.0     89   Pass
# 10          10   18  Female           6        96.0     89   Pass

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#    student_id  age  gender  studyhours  attendance  marks result
# 0           1   18    Male           4        92.0     85   Pass
# 1           2   19  Female           6        95.0     91   Pass
# 6           7   21    Male           5        90.0     88   Pass
# 8           9   19    Male           1        60.0     38   Fail
# 9          10   18  Female           6        96.0     89   Pass

# %%
df.describe()
# Out:
#        student_id        age  studyhours  attendance      marks
# count    5.000000   5.000000    5.000000     5.00000   5.000000
# mean     5.800000  19.000000    4.400000    86.60000  78.200000
# std      4.086563   1.224745    2.073644    15.05988  22.576536
# min      1.000000  18.000000    1.000000    60.00000  38.000000
# 25%      2.000000  18.000000    4.000000    90.00000  85.000000
# 50%      7.000000  19.000000    5.000000    92.00000  88.000000
# 75%      9.000000  19.000000    6.000000    95.00000  89.000000
# max     10.000000  21.000000    6.000000    96.00000  91.000000

# %%
df['marks'] = pd.to_numeric(df['marks'], errors='coerce')
df['marks'] = df['marks'].fillna(df['marks'].median())

plt.hist(df['marks'],bins=10)
plt.xlabel("marks")
plt.ylabel("Frequency")
plt.title("Distribution of Marks")
plt.show()

# %%
corr = df[["studyhours", "marks"]].corr()

print(corr)
# Out:
#             studyhours   marks
# studyhours      1.0000  0.9484
# marks           0.9484  1.0000

# %%
df.shape
df.isnull().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.shape,
df.isnull().sum(),
df.duplicated().sum())
# Out:
# (5, 7) student_id    0
# age           0
# gender        0
# studyhours    0
# attendance    0
# marks         0
# result        0
# dtype: int64 0
